# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/silviaresende/Documents/TOP/TOP23/data/2010_zcta_to_county.csv')

# %%
df.tail(10)
# Out:
#        ZCTA5  STATE  COUNTY  GEOID  POPPT  HUPT      AREAPT  AREALANDPT  ZPOP  \
# 44400  99903      2     275   2275     31    69   456712842   401532954    31
# 44401  99918      2     198   2198    231   223   107717006    95158906   231
# 44402  99919      2     198   2198    531   409   143670987   125279693   531
# 44403  99921      2     198   2198   1920  1077  6417202419  5284962602  1920
# 44404  99922      2     198   2198    384   140   318532537   297631982   384
# 44405  99923      2     198   2198     87    90    35939636    35937519    87
# 44406  99925      2     198   2198    819   400   181409664   144503281   819
# 44407  99926      2     198   2198   1460   544   557283125   343947256  1460
# 44408  99927      2     198   2198     94   101   607689356   589688205    94
# 44409  99929      2     275   2275   2338  1339  6235969341  5598556684  2338
#
#         ZHU  ...       COAREA   COAREALAND  ZPOPPCT  ZHUPCT  ZAREAPCT  \
# ...

# %%
df.columns
# Out:
# Index(['ZCTA5', 'STATE', 'COUNTY', 'GEOID', 'POPPT', 'HUPT', 'AREAPT',
#        'AREALANDPT', 'ZPOP', 'ZHU', 'ZAREA', 'ZAREALAND', 'COPOP', 'COHU',
#        'COAREA', 'COAREALAND', 'ZPOPPCT', 'ZHUPCT', 'ZAREAPCT', 'ZAREALANDPCT',
#        'COPOPPCT', 'COHUPCT', 'COAREAPCT', 'COAREALANDPCT'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44410 entries, 0 to 44409
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ZCTA5          44410 non-null  int64
#  1   STATE          44410 non-null  int64
#  2   COUNTY         44410 non-null  int64
#  3   GEOID          44410 non-null  int64
#  4   POPPT          44410 non-null  int64
#  5   HUPT           44410 non-null  int64
#  6   AREAPT         44410 non-null  int64
#  7   AREALANDPT     44410 non-null  int64
#  8   ZPOP           44410 non-null  int64
#  9   ZHU            44410 non-null  int64
#  10  ZAREA          44410 non-null  int64
#  11  ZAREALAND      44410 non-null  int64
#  12  COPOP          44410 non-null  int64
#  13  COHU           44410 non-null  int64
#  14  COAREA         44410 non-null  int64
#  15  COAREALAND     44410 non-null  int64
#  16  ZPOPPCT        44410 non-null  float64
#  17  ZHUPCT         44410 non-null  float64
# ...

# %%
df[df['ZCTA5'] == 98125 ]
# Out:
#        ZCTA5  STATE  COUNTY  GEOID  POPPT   HUPT    AREAPT  AREALANDPT   ZPOP  \
# 43550  98125     53      33  53033  37081  18677  17937292    13960901  37081
#
#          ZHU  ...      COAREA  COAREALAND  ZPOPPCT  ZHUPCT  ZAREAPCT  \
# 43550  18677  ...  5974763073  5479291809    100.0   100.0     100.0
#
#        ZAREALANDPCT  COPOPPCT  COHUPCT  COAREAPCT  COAREALANDPCT
# 43550         100.0      1.92     2.19        0.3           0.25
#
# [1 rows x 24 columns]

# %%
data = df[['ZCTA5', 'STATE', 'COUNTY' ]]

# %%
data.to_csv('../data/zipcode_to_county.csv')
